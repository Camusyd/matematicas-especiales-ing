# %%
# -*- coding: utf-8 -*-
# <nbformat>4.4</nbformat>

# 📚 EJERCICIOS RESUELTOS: EDO DE ORDEN SUPERIOR NO HOMOGÉNEAS
# Autor: Juan Pablo C J

# Importación de librerías esenciales
import sympy as sp
from sympy import Function, dsolve, Eq, Derivative, symbols

# Definición de la variable independiente y la función desconocida
x = symbols('x')
y = Function('y')

# =================================================================
## EJERCICIO 1: Método de Coeficientes Indeterminados (Para la práctica conceptual)
# EDO: y'' - 3y' - 4y = 2e^(-x)

print("--- EJERCICIO 1: Coeficientes Indeterminados ---")
# 1. Definición de la ecuación diferencial
eq = Eq(Derivative(y(x), x, 2) - 3*Derivative(y(x), x, 1) - 4*y(x), 2*sp.exp(-x))
print(f"Ecuación a resolver: {eq}")

# 2. Solución analítica usando SymPy
sol = dsolve(eq, y(x))
print(f"Solución General y(x) = yc(x) + yp(x): {sol.rhs}")

# 3. Análisis de la Solución:
#    - Las constantes C1 y C2 corresponden a la solución complementaria (yc).
#    - El término -x/2 * exp(-x) es la forma de la solución particular (yp) ajustada por resonancia.

print("\n")
# =================================================================
## EJERCICIO 2: Ecuación de Cauchy-Euler (Para la parte Homogénea o EDO completa)
# EDO: x^2*y'' + 3*x*y' + y = x

print("--- EJERCICIO 2: Ecuación de Cauchy-Euler No Homogénea ---")
# 1. Definición de la Ecuación
eq_ce = Eq(x**2 * Derivative(y(x), x, 2) + 3*x * Derivative(y(x), x, 1) + y(x), x)
print(f"Ecuación a resolver: {eq_ce}")

# 2. Solución analítica
sol_ce = dsolve(eq_ce, y(x))
print(f"Solución General y(x): {sol_ce.rhs}")

# 3. Comprobación y Análisis (Este ejercicio requiere el uso de Variación de Parámetros o métodos avanzados para la yp)
#    - La solución yc está compuesta por C1/x + C2*log(x)/x.
#    - La solución yp es el término restante.

# Nota: Para el método de Variación de Parámetros completo, la implementación manual o con funciones específicas
# de SymPy fuera de dsolve puede ser necesaria, ya que dsolve elige el método más eficiente.
# Out:
# --- EJERCICIO 1: Coeficientes Indeterminados ---
# Ecuación a resolver: Eq(-4*y(x) - 3*Derivative(y(x), x) + Derivative(y(x), (x, 2)), 2*exp(-x))
# Solución General y(x) = yc(x) + yp(x): C2*exp(4*x) + (C1 - 2*x/5)*exp(-x)
#
#
# --- EJERCICIO 2: Ecuación de Cauchy-Euler No Homogénea ---
# Ecuación a resolver: Eq(x**2*Derivative(y(x), (x, 2)) + 3*x*Derivative(y(x), x) + y(x), x)
# Solución General y(x): (C1 + C2*log(x) + x**2/4)/x
