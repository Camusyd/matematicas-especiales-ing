# %%
# Contenido de ejercicios.ipynb - Celda 1

# Importamos las librerías esenciales para el cálculo y análisis simbólico.
import numpy as np
import sympy as sp
from sympy.abc import x, y, z, r, theta

# %% [markdown]
# ## 🚀 1. Conversiones y Representación de Números Complejos
# ### Objetivo
# Practicar la conversión entre las formas rectangular ($x+iy$), polar ($r(\cos\theta + i\sin\theta)$), y exponencial ($re^{i\theta}$) de un número complejo.
#
# **Ejercicio 1.1:** Dado $z = 1 + i\sqrt{3}$, encuentre su módulo ($r$), argumento ($\theta$) y su forma exponencial.

# %%
# Contenido de ejercicios.ipynb - Celda 3

# Definición del número complejo
z_val = 1 + sp.I * sp.sqrt(3)

# Cálculo del módulo (r)
r_val = sp.Abs(z_val)

# Cálculo del argumento (theta)
theta_val = sp.arg(z_val)

print(f"Número Rectangular (z): {z_val}")
print(f"Módulo (r): {r_val}")
# El argumento es pi/3 radianes
print(f"Argumento (theta): {theta_val} (aproximadamente {theta_val.evalf()} rad)")

# Forma Exponencial: r * e^(i*theta)
z_exp = r_val * sp.exp(sp.I * theta_val)
print(f"Forma Exponencial: {z_exp}")
# Out:
# Número Rectangular (z): 1 + sqrt(3)*I
# Módulo (r): 2
# Argumento (theta): pi/3 (aproximadamente 1.04719755119660 rad)
# Forma Exponencial: 2*exp(I*pi/3)

# %% [markdown]
# ## 🧪 2. Verificación de las Ecuaciones de Cauchy-Riemann (C-R)
#
# ### Objetivo
# Determinar si una función $f(z) = u(x, y) + i v(x, y)$ es **analítica** verificando si sus partes real e imaginaria cumplen las Ecuaciones de Cauchy-Riemann.
#
# **Ecuaciones de C-R:**
# 1. $\frac{\partial u}{\partial x} = \frac{\partial v}{\partial y}$
# 2. $\frac{\partial u}{\partial y} = -\frac{\partial v}{\partial x}$
#
# **Ejercicio 2.1:** Analizar la función $f(z) = z^2$.
# Dado que $z^2 = (x+iy)^2 = (x^2 - y^2) + i(2xy)$, entonces:
# * $u(x, y) = x^2 - y^2$
# * $v(x, y) = 2xy$

# %%
# Contenido de ejercicios.ipynb - Celda 5

# Definición de las partes real (u) e imaginaria (v)
u = x**2 - y**2
v = 2 * x * y

# Cálculo de las cuatro derivadas parciales
du_dx = sp.diff(u, x)
dv_dy = sp.diff(v, y)
du_dy = sp.diff(u, y)
dv_dx = sp.diff(v, x)

print("### Derivadas Parciales ###")
print(f"du/dx = {du_dx}")
print(f"dv/dy = {dv_dy}")
print(f"du/dy = {du_dy}")
print(f"dv/dx = {dv_dx}")
print("-" * 30)

# Verificación de la Primera Ecuación de C-R: du/dx = dv/dy
c1_check = sp.simplify(du_dx - dv_dy)
print(f"Check 1 (du/dx - dv/dy): {c1_check}. Criterio: {c1_check == 0}")

# Verificación de la Segunda Ecuación de C-R: du/dy = -dv/dx
c2_check = sp.simplify(du_dy + dv_dx)
print(f"Check 2 (du/dy + dv/dx): {c2_check}. Criterio: {c2_check == 0}")

if c1_check == 0 and c2_check == 0:
    print("\n✅ La función f(z) = z^2 CUMPLE las Ecuaciones de Cauchy-Riemann y es ANALÍTICA.")
else:
    print("\n❌ La función NO es analítica.")
# Out:
# ### Derivadas Parciales ###
# du/dx = 2*x
# dv/dy = 2*x
# du/dy = -2*y
# dv/dx = 2*y
# ------------------------------
# Check 1 (du/dx - dv/dy): 0. Criterio: True
# Check 2 (du/dy + dv/dx): 0. Criterio: True
#
# ✅ La función f(z) = z^2 CUMPLE las Ecuaciones de Cauchy-Riemann y es ANALÍTICA.

# %% [markdown]
# ## 🌊 3. Determinación de Funciones Armónicas Conjugadas
#
# ### Objetivo
# Dada una función armónica $u(x, y)$, encontrar su conjugada armónica $v(x, y)$ tal que $f(z) = u + iv$ sea una función analítica. El proceso se basa en integrar las Ecuaciones de C-R.
#
# **Ejercicio 3.1:** Sea $u(x, y) = x^2 - y^2 + x$. Encontrar $v(x, y)$.
#
# **Pasos:**
# 1. Usar $\partial v / \partial y = \partial u / \partial x$. Integrar respecto a $y$.
# 2. Usar $\partial v / \partial x = -\partial u / \partial y$. Derivar el resultado del paso 1 y comparar.

# %%
# Contenido de ejercicios.ipynb - Celda 7

u_armonica = x**2 - y**2 + x

# Paso 1: Usar d/dy = d/dx
# d/dx(u) = 2x + 1
du_dx_arm = sp.diff(u_armonica, x)

# Integrar respecto a y para obtener v(x, y) = (2x + 1)y + h(x)
# SymPy no maneja la constante h(x), por lo que lo hacemos manualmente.
# dv/dy = 2x + 1  =>  v(x, y) = (2x + 1)y + h(x) 

# Paso 2: Usar d/dx(v) = -d/dy(u)
# d/dy(u) = -2y
du_dy_arm = sp.diff(u_armonica, y)

# Por la segunda C-R, dv/dx debe ser igual a -(-2y) = 2y
dv_dx_target = -du_dy_arm
# dv/dx_target = 2y

# Derivamos v(x, y) respecto a x: d/dx [ (2x + 1)y + h(x) ] = 2y + h'(x)
# Igualamos: 2y + h'(x) = 2y
# Esto implica que h'(x) = 0, por lo tanto, h(x) = C (constante real).

v_conjugada = 2 * x * y + y # Esta es la parte de la integración: (2x + 1)y
v_conjugada_simplificada = v_conjugada + sp.Symbol('C')

print(f"Función armónica u(x, y): {u_armonica}")
print(f"dv/dx (Target): {dv_dx_target}")
print(f"Función conjugada armónica v(x, y) = 2xy + y + C")
# Out:
# Función armónica u(x, y): x**2 + x - y**2
# dv/dx (Target): 2*y
# Función conjugada armónica v(x, y) = 2xy + y + C
