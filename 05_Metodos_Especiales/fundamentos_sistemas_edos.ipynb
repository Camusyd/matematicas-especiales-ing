# %% [markdown]
# # 🏛️ Fundamentos y Clasificación de Sistemas de EDOs
#
# ## 🎯 Objetivo
#
# Comprender la estructura fundamental de los sistemas de Ecuaciones Diferenciales Ordinarias (EDOs), su clasificación esencial y por qué son la herramienta predilecta para modelar **sistemas dinámicos acoplados** en ingeniería y física.
#
# ## 📝 ¿Qué es un Sistema de EDOs?
#
# Un **Sistema de EDOs** es un conjunto de dos o más ecuaciones que involucran las derivadas de dos o más funciones desconocidas. Estas ecuaciones están **acopladas**, lo que significa que la derivada de una función depende de las otras funciones.
#
# La forma general de un sistema de primer orden con $n$ variables dependientes ($x_1, x_2, \dots, x_n$) es:
#
# $$
# \begin{cases} \mathbf{x'_1 = f_1(t, x_1, x_2, \dots, x_n)} \\ \mathbf{x'_2 = f_2(t, x_1, x_2, \dots, x_n)} \\ \vdots \\ \mathbf{x'_n = f_n(t, x_1, x_2, \dots, x_n)} \end{cases}
# $$
#
# **Aplicación Clave:** Los sistemas de EDOs surgen naturalmente al modelar la interacción de dos o más masas conectadas por resortes, sistemas depredador-presa o circuitos eléctricos complejos.

# %%
# Importación de librerías necesarias
import sympy as sp
from sympy import Function, dsolve, Eq, Derivative, symbols, Matrix, zeros

# Definición de la variable independiente (tiempo)
t = symbols('t')

# Definición de las funciones desconocidas (variables dependientes)
x1 = Function('x1')(t)
x2 = Function('x2')(t)

print("Símbolos y variables definidas, listos para la clasificación.")
# Out:
# Símbolos y variables definidas, listos para la clasificación.

# %% [markdown]
# ## ⚖️ Clasificación de los Sistemas de EDOs
#
# Los sistemas se clasifican según la dependencia de las variables y si contienen o no términos de forzamiento.
#
# ### 1. Linealidad (La más Importante)
#
# #### A. Sistemas Lineales
# Un sistema es lineal si todas las funciones $f_i$ son funciones lineales de las variables dependientes ($x_1, x_2, \dots, x_n$).
# * **Ejemplo:** $x'_1 = 3x_1 - 2x_2$
# * **Importancia:** Permiten el uso de **métodos matriciales** (autovalores y autovectores) para obtener soluciones analíticas y realizar el análisis de estabilidad.
#
# #### B. Sistemas No Lineales
# Un sistema es no lineal si al menos una de las ecuaciones contiene productos de las funciones desconocidas, potencias, o funciones trascendentales de ellas.
# * **Ejemplo:** $x'_1 = x_1 x_2 - 5x_1$
# * **Importancia:** Requieren **linealización** para analizar su estabilidad cerca de los puntos de equilibrio (Temática de Nivel 3).
#
# ### 2. Homogeneidad
#
# #### A. Sistemas Homogéneos
# El sistema es homogéneo si no hay términos de forzamiento o funciones que dependan solo de $t$ (la variable independiente).
# * **Forma matricial (Lineal):** $\mathbf{X' = A X}$
# * **Ejemplo:** El sistema que modela el movimiento libre de un resorte.
#
# #### B. Sistemas No Homogéneos
# El sistema es no homogéneo si incluye un **vector de forzamiento** $\mathbf{G(t)}$ que depende solo de la variable independiente $t$.
# * **Forma matricial (Lineal):** $\mathbf{X' = A X + G(t)}$
# * **Ejemplo:** El sistema que modela un sistema masa-resorte sometido a una fuerza externa periódica.

# %% [markdown]
# ## 🧩 Representación Matricial (El Modelo Ideal)
#
# El formato más útil para la resolución y el análisis en **Matemáticas Especiales** es el formato matricial para sistemas lineales de primer orden.
#
# Consideremos el sistema lineal homogéneo:
# $$
# \begin{cases} x'_1 = 0 x_1 + 1 x_2 \\ x'_2 = -3 x_1 - 4 x_2 \end{cases}
# $$
# (Este sistema fue obtenido al transformar la EDO $y'' + 4y' + 3y = 0$).
#
# Este sistema se representa matricialmente como:
# $$
# \mathbf{\frac{d\mathbf{X}}{dt} = \mathbf{A} \mathbf{X}}
# $$
# Donde:
# * $\mathbf{X} = \begin{pmatrix} x_1 \\ x_2 \end{pmatrix}$ (Vector de Estado)
# * $\mathbf{A} = \begin{pmatrix} 0 & 1 \\ -3 & -4 \end{pmatrix}$ (Matriz de Coeficientes)

# %%
# --- Representación Matricial del Sistema ---

# 1. Definir la Matriz de Coeficientes A
A = Matrix([[0, 1], [-3, -4]])

print("--- Matriz de Coeficientes del Sistema (A) ---")
print(A)

# 2. Definir el Vector de Estado X
X = Matrix([[x1], [x2]])

print("\n--- Vector de Estado (X) ---")
print(X)

# En el análisis de sistemas dinámicos, la solución del sistema X(t) se encuentra
# mediante el cálculo de los eigenvalores (valores propios) y eigenvectores (vectores propios) de la matriz A.
# Estos determinan la estabilidad y el comportamiento a largo plazo (el retrato de fase) del sistema.
# Out:
# --- Matriz de Coeficientes del Sistema (A) ---
# Matrix([[0, 1], [-3, -4]])
#
# --- Vector de Estado (X) ---
# Matrix([[x1(t)], [x2(t)]])
